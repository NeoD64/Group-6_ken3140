# %% [markdown]
# first we need to populate with 50 products

# %%
import pandas as pd

BASE_URI = "https://www.hp.com/resource/product/"

products_data = [
    {
        "item_uri": BASE_URI + "laptop_omen_16",
        "schema_name": "OMEN Gaming Laptop 16-wf0000",
        "schema_url": "https://www.hp.com/us-en/shop/pdp/omen-gaming-laptop-16-wf0000",
        "subcategory": "GamingLaptop",
        "brand": "OMEN",
        "schema_price": 1299.99,
        "schema_model": "16-wf0000",
        "schema_operatingSystem": "Windows 11 Home",
    },
    {
        "item_uri": BASE_URI + "laptop_pavilion_15",
        "schema_name": "HP Pavilion Laptop 15-eg3000",
        "schema_url": "https://www.hp.com/us-en/shop/pdp/hp-pavilion-laptop-15-eg3000",
        "subcategory": "BudgetLaptop",
        "brand": "HP",
        "schema_price": 549.99,
        "schema_model": "15-eg3000",
        "schema_operatingSystem": "Windows 11 Home",
    },
    {
        "item_uri": BASE_URI + "desktop_z2_tower",
        "schema_name": "HP Z2 Tower G9 Workstation",
        "schema_url": "https://www.hp.com/us-en/shop/pdp/hp-z2-tower-g9-workstation",
        "subcategory": "Workstation",
        "brand": "HP",
        "schema_price": 1849.00,
        "schema_model": "Z2-G9",
        "schema_operatingSystem": "Windows 11 Pro",
    },
    {
        "item_uri": BASE_URI + "printer_officejet_8015e",
        "schema_name": "HP OfficeJet Pro 8015e Wireless Printer",
        "schema_url": "https://www.hp.com/us-en/shop/pdp/hp-officejet-pro-8015e",
        "subcategory": "InkjetPrinter",
        "brand": "HP",
        "schema_price": 159.99,
        "schema_model": "8015e",
        "schema_operatingSystem": "N/A",
    },

    {
        "item_uri": BASE_URI + "accessory_hyperx_cloud",
        "schema_name": "HyperX Cloud III Wireless Gaming Headset",
        "schema_url": "https://www.hp.com/us-en/shop/pdp/hyperx-cloud-iii-wireless",
        "subcategory": "Category",
        "brand": "HyperX",
        "schema_price": 149.99,
        "schema_model": "Cloud-III",
        "schema_operatingSystem": "N/A",
    },
]

df = pd.DataFrame(products_data)

df.to_csv("6_ken3140_webshop.csv", index=False)
